# %%
from Bio import Entrez
Entrez.email = "wuchangsheng@sdu.edu.cn"
import os
import pickle
import json
import lzma
from datetime import date
from time import strftime, sleep
from urllib.error import HTTPError
from http.client import IncompleteRead
import sys
from Bio import SeqIO
from Bio import Seq
import subprocess

# Set these 3 parameter
prefix = "txid29"
searchTerm = f'{prefix}[Organism] AND refseq[filter] NOT "sequencing project"[Title]'
targetDir = "/mnt/sdb/wcs/NCBI-myxobacterial-genome"
######

searchStatusFile = os.path.join(targetDir, 'searchStatus.json')
if os.path.isfile(searchStatusFile):
    with open(searchStatusFile,'r') as h:
        newSearch, dateOfSearch, start, downloadStep = json.load(h)
else:
    newSearch = True
    start = 0
    dateOfSearch = date.today().strftime("%Y%m%d")
    downloadStep = 1 # this may change only when you start a new search


def writeLog(logFile, logStr, end = '\n'):
    print(logStr, end = end)
    with open(logFile,'a') as logHandle:
        logHandle.write(f'{logStr}{end}')

# %% [markdown]
# * Taxonomy ID: 228398 (for references in articles please use NCBI:txid228398)
#  Scientific name: Streptacidiphilus Kim et al. 2003
# * Taxonomy ID: 2063 (for references in articles please use NCBI:{prefix})
#  Scientific name: Kitasatospora corrig. Omura et al. 1983 emend. Zhang et al. 1997
# * Taxonomy ID: 1883 (for references in articles please use NCBI:txid1883)
#  Scientific name: Streptomyces Waksman and Henrici 1943 (Approved Lists 1980) emend. Wellington et al. 199*
# * Taxonomy ID: 1914443 (for references in articles please use NCBI:txid1914443)
#  Scientific name: Allostreptomyces Huang et al. 2017
# * Taxonomy ID: 329648 (for references in articles please use NCBI:txid329648)
#  Scientific name: "Parastreptomyces" 1) Nichols et al. 2005
# * Taxonomy ID: 65518 (for references in articles please use NCBI:txid65518)
#  Scientific name: "Trichotomospora" 1) Lian et al. 1985
# * Taxonomy ID: 234292 (for references in articles please use NCBI:txid234292)
#  Scientific name: unclassified Streptomycetaceae
# * Taxonomy ID: 259296 (for references in articles please use NCBI:txid259296)
#  Scientific name: environmental samples

# %%
def getRecords(searchTerm, c = 0, step = 2000, webaccession = None, targets = []):
    count = 0
    while c < count or count == 0:
        print(f'No.{int(c/step+1)}', end = '>')
        handle = Entrez.esearch(db='nuccore', 
                                term=searchTerm,
                                usehistory=True,
                                webenv=webaccession, # reuse teh first query
                                retstart=c, # Continue from num c
                                retmax=step # Maxium number returned
                               )
        record = Entrez.read(handle)
        handle.close()
        if record['Count'] == "0":
            print("\nThere is no genome with this search.")
            break
        if 'WarningList' in record: # If anything wrong
            print(record['WarningList']['OutputMessage'])

        # Put current list of IDs in our targets dict    
        targets.append(record['IdList'])
        print(f"{len(record['IdList'])}", end = '|')  # the number got from this loop.

        if webaccession == None:
            webaccession = record["WebEnv"] # start new search only in the first loop
            print(f'\nWebAccession:\n{webaccession}')
            count = int(record['Count']) # total number of hits get from the first search attempt
            print(f"Total entry {count}.")    
        c += step
    return c, count, webaccession, targets

# %%
if newSearch:
    if "webaccession" in globals():
        c, count, webaccession, targets = getRecords(searchTerm=searchTerm, c=c, step=200, webaccession=webaccession, targets=targets)
    else:
        c, count, webaccession, targets = getRecords(searchTerm = searchTerm, step=200)

    # now print and check the first 5 IDs of the first 10 lists of IDs
    print(f"\nTotal target sets {len(targets)}\nFirst 10:")
    for targ in targets[:10]:
        print(f"{targ[:5]}...")
    print('...')
else:
    print('Skip')

# %% [markdown]
# # Fetching all data from online (getting IDs from previous stored data)

# %%
# Dump targets got from search in pickle file
targetsJson = os.path.join(targetDir, f'refseq_{prefix}_{dateOfSearch}.json')
print(targetsJson)
print(newSearch)

if newSearch:
    with open(targetsJson, 'w') as to:
        json.dump(targets, to)
    newSearch = False # switch off newSearch
else:
    with open(targetsJson, 'r') as ti:
        targets = json.load(ti)
        
# flatten the targets list of list
# remove redundant if we have somene


nucids = sorted(list(set(item for sublist in targets for item in sublist)))
print(f"Total nucids {len(nucids)}\nRemember to switch off <newSearch>")

# %%
from multiprocessing import Process, Queue

def fetch(succeed, index, file_Nu, ids, returnType = ['fasta','fasta']):
    
    '''fetch(index, file_Nu, ids, returnType = ['fasta','fasta'])
    
    other option is:
    returnType = ['gbwithparts','gb']'''

    writeLog(logFile, f"Fetching {file_Nu}: {ids[0]}...({len(ids)})")
    
    output_file = os.path.join(outputPath, f'{prefix}_No_{file_Nu}.{returnType[1]}')

    # Fetching...
    with Entrez.efetch(db = 'nuccore',
                       id = ids,
                       rettype = returnType[0],
                       retmode = 'text'
                      ) as handle:
        with open(output_file, 'w') as out_handle:
            out_handle.write(handle.read())
    
    # Write finishing note to screen and log file
    logstr = f"Finished {file_Nu}: {os.stat(output_file).st_size/1024/1024:.2f} MB {output_file} \n"
    print(logstr)
    with open(logFile,'a') as log_handle:
        log_handle.write(f'{logstr}\n')
    #return True
    succeed.put(True)


def finishing(allDone = True):
    totalSize = 0 # calculate total amount data got from entrez
    for file in os.listdir(outputPath):
        if file.endswith('.gb') or file.endswith('.fasta'):
            totalSize += os.stat(os.path.join(outputPath,file)).st_size
    
    writeLog(logFile, f"Group finished, already got {totalSize/1024/1024:.2f} MB data!")
    if allDone:
            writeLog(logFile,'Finished fetching all IDs.')
    else:
        writeLog(logFile, f'Next download will start from group {start} (of 0 - {len(idStacks)-1}).')
        writeLog(logFile, f'{timestamp:*^80}')
        print('Before starting next query, please set how many groups you want to fetch based on your schedule.')        

def fetchData(start, idStacks, getSingleBatch = False):
    for i in range(start, len(idStacks)):
        # Break the loop for shorter operation and debugging time
        if i == end and i != len(idStacks)-1:
            start = i
            finishing(allDone = False)
            return True, start

        ids = idStacks[i]

        succeed = False
        retryTimes = 0
        while succeed == False:
            try:
                processSucceed = Queue()
                fetch_process = Process(target = fetch, kwargs={'index':i,
                                                                'succeed':processSucceed,
                                                                'file_Nu':str(i).zfill(5),
                                                                'ids':ids,
                                                                'returnType':['gbwithparts','gb']
                                                               })
                fetch_process.start()
                fetch_process.join(timeout=60*60)
                if processSucceed.empty():
                    raise Exception
                else:
                    succeed = processSucceed.get()
                #succeed = fetch(index = i, file_Nu = str(i).zfill(4), ids = ids, returnType = ['gbwithparts','gb'])
            except (HTTPError, IncompleteRead):
                retryTimes += 1
                if retryTimes == 10:
                    writeLog(logFile,"Failed 10 times due to HTTPError (NCBI server problem), please try again another time.")
                    start = i
                    writeLog(logFile,f'Start value set for next trial. [{start}]')
                    return False, start
                else:
                    writeLog(logFile,'Failed due to HTTPError, pause for 45 seconds...',end = '')
                    sleep(45)
                    writeLog(logFile,'Retrying...')
            except Exception as e:
                start = i
                writeLog(logFile,f'Failed due to uncought error\n{e}\nStart value set for next trial. [{start}]')

                return False, start
            finally:
                with open(searchStatusFile,'w') as h:
                    json.dump([False, dateOfSearch, start, downloadStep], h)
        if not succeed:
            writeLog(logFile,"I don't know what happend, ask DU")
            return False, start
        elif i == len(idStacks) - 1:
            finishing(allDone = True)
            return True, 0
        if getSingleBatch:
            break
            return True, 0

# %%
# For debugging
start = 1271 # should start from 0 if nothing have downloaded
downloadStep=1
# getSingleBatch = False

# %%
# define how many sequences to download in each group
idStacks = []
for i in range(0,len(nucids),downloadStep):
    idStacks.append(nucids[i:i+downloadStep])

print(f'Last group No. {str(len(idStacks)-1).zfill(5)}')

numToFetch = 99999 # number of files to fetch (specifing if you can not finish in one go)

end = start + numToFetch # range(start, end) means not including end number!!

if end > len(idStacks):
    end = len(idStacks)

outputPath = r"/mnt/sdb/wcs/NCBI-myxobacterial-genome"
logFile = os.path.join(outputPath, f'fetching.log')
timestamp = strftime('%X %d/%m/%Y %Z')

writeLog(logFile, f'\n{timestamp:*^80}\nNow fetching groups from {start} to {end-1}\nEach group have {downloadStep} nuclIDs\nIDs from {start*downloadStep+1} to {end*downloadStep+1-1} (inclusive)\n{"":*^80}\n')
# Mean loop
isDone, start = fetchData(start,idStacks)
while not isDone:
    isDone, start = fetchData(start,idStacks)
    sleep(15)
# Out:
# Finished 23273: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23273.gb
#
# Fetching 23274: 1697872765...(1)
# Finished 23274: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23274.gb
#
# Fetching 23275: 1697872767...(1)
# Finished 23275: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23275.gb
#
# Fetching 23276: 1697872770...(1)
# Finished 23276: 0.00 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23276.gb
#
# Fetching 23277: 1697872772...(1)
# Finished 23277: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23277.gb
#
# Fetching 23278: 1697872774...(1)
# Finished 23278: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23278.gb
#
# Fetching 23279: 1697872776...(1)
# Finished 23279: 0.00 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23279.gb
#
# Fetching 23280: 1697872778...(1)
# Finished 23280: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23280.gb
#
# Fetching 23281: 1698391930...(1)
# Finished 23281: 0.59 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23281.gb
#
# Fetching 23282: 1698391949...(1)
# Finished 23282: 0.48 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23282.gb
#
# Fetching 23283: 1698391962...(1)
# Finished 23283: 0.45 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23283.gb
#
# Fetching 23284: 1698391974...(1)
# Finished 23284: 0.41 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23284.gb
#
# Fetching 23285: 1698391987...(1)
# Finished 23285: 0.38 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23285.gb
#
# Fetching 23286: 1698391998...(1)
# Finished 23286: 0.35 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23286.gb
#
# Fetching 23287: 1698392007...(1)
# Finished 23287: 0.32 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23287.gb
#
# Fetching 23288: 1698392017...(1)
# Finished 23288: 0.35 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23288.gb
#
# Fetching 23289: 1698392029...(1)
# Finished 23289: 0.35 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23289.gb
#
# Fetching 23290: 1698392041...(1)
# Finished 23290: 0.34 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23290.gb
#
# Fetching 23291: 1698392051...(1)
# Finished 23291: 0.32 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23291.gb
#
# Fetching 23292: 1698392061...(1)
# Finished 23292: 0.30 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23292.gb
#
# Fetching 23293: 1698392071...(1)
# Finished 23293: 0.31 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23293.gb
#
# Fetching 23294: 1698392081...(1)
# Finished 23294: 0.29 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23294.gb
#
# Fetching 23295: 1698392091...(1)
# Finished 23295: 0.28 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23295.gb
#
# Fetching 23296: 1698392099...(1)
# Finished 23296: 0.23 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23296.gb
#
# Fetching 23297: 1698392106...(1)
# Finished 23297: 0.26 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23297.gb
#
# Fetching 23298: 1698392114...(1)
# Finished 23298: 0.24 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23298.gb
#
# Fetching 23299: 1698392121...(1)
# Finished 23299: 0.26 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23299.gb
#
# Fetching 23300: 1698392130...(1)
# Finished 23300: 0.25 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23300.gb
#
# Fetching 23301: 1698392138...(1)
# Finished 23301: 0.22 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23301.gb
#
# Fetching 23302: 1698392149...(1)
# Finished 23302: 0.22 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23302.gb
#
# Fetching 23303: 1698392157...(1)
# Finished 23303: 0.22 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23303.gb
#
# Fetching 23304: 1698392165...(1)
# Finished 23304: 0.23 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23304.gb
#
# Fetching 23305: 1698392174...(1)
# Finished 23305: 0.21 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23305.gb
#
# Fetching 23306: 1698392181...(1)
# Finished 23306: 0.20 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23306.gb
#
# Fetching 23307: 1698392188...(1)
# Finished 23307: 0.20 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23307.gb
#
# Fetching 23308: 1698392195...(1)
# Finished 23308: 0.18 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23308.gb
#
# Fetching 23309: 1698392201...(1)
# Finished 23309: 0.20 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23309.gb
#
# Fetching 23310: 1698392209...(1)
# Finished 23310: 0.20 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23310.gb
#
# Fetching 23311: 1698392215...(1)
# Finished 23311: 0.18 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23311.gb
#
# Fetching 23312: 1698392220...(1)
# Finished 23312: 0.19 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23312.gb
#
# Fetching 23313: 1698392226...(1)
# Finished 23313: 0.19 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23313.gb
#
# Fetching 23314: 1698392232...(1)
# Finished 23314: 0.17 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23314.gb
#
# Fetching 23315: 1698392238...(1)
# Finished 23315: 0.17 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23315.gb
#
# Fetching 23316: 1698392244...(1)
# Finished 23316: 0.18 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23316.gb
#
# Fetching 23317: 1698392250...(1)
# Finished 23317: 0.17 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23317.gb
#
# Fetching 23318: 1698392256...(1)
# Finished 23318: 0.16 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23318.gb
#
# Fetching 23319: 1698392262...(1)
# Finished 23319: 0.16 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23319.gb
#
# Fetching 23320: 1698392268...(1)
# Finished 23320: 0.16 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23320.gb
#
# Fetching 23321: 1698392277...(1)
# Finished 23321: 0.17 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23321.gb
#
# Fetching 23322: 1698392284...(1)
# Finished 23322: 0.16 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23322.gb
#
# Fetching 23323: 1698392290...(1)
# Finished 23323: 0.16 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23323.gb
#
# Fetching 23324: 1698392295...(1)
# Finished 23324: 0.16 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23324.gb
#
# Fetching 23325: 1698392302...(1)
# Finished 23325: 0.16 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23325.gb
#
# Fetching 23326: 1698392308...(1)
# Finished 23326: 0.16 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23326.gb
#
# Fetching 23327: 1698392314...(1)
# Finished 23327: 0.17 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23327.gb
#
# Fetching 23328: 1698392319...(1)
# Finished 23328: 0.15 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23328.gb
#
# Fetching 23329: 1698392324...(1)
# Finished 23329: 0.13 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23329.gb
#
# Fetching 23330: 1698392329...(1)
# Finished 23330: 0.16 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23330.gb
#
# Fetching 23331: 1698392335...(1)
# Finished 23331: 0.16 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23331.gb
#
# Fetching 23332: 1698392341...(1)
# Finished 23332: 0.15 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23332.gb
#
# Fetching 23333: 1698392347...(1)
# Finished 23333: 0.14 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23333.gb
#
# Fetching 23334: 1698392353...(1)
# Finished 23334: 0.13 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23334.gb
#
# Fetching 23335: 1698392357...(1)
# Finished 23335: 0.13 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23335.gb
#
# Fetching 23336: 1698392362...(1)
# Finished 23336: 0.14 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23336.gb
#
# Fetching 23337: 1698392368...(1)
# Finished 23337: 0.14 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23337.gb
#
# Fetching 23338: 1698392374...(1)
# Finished 23338: 0.12 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23338.gb
#
# Fetching 23339: 1698392379...(1)
# Finished 23339: 0.13 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23339.gb
#
# Fetching 23340: 1698392385...(1)
# Finished 23340: 0.12 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23340.gb
#
# Fetching 23341: 1698392389...(1)
# Finished 23341: 0.13 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23341.gb
#
# Fetching 23342: 1698392394...(1)
# Finished 23342: 0.11 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23342.gb
#
# Fetching 23343: 1698392398...(1)
# Finished 23343: 0.12 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23343.gb
#
# Fetching 23344: 1698392403...(1)
# Finished 23344: 0.12 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23344.gb
#
# Fetching 23345: 1698392407...(1)
# Finished 23345: 0.12 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23345.gb
#
# Fetching 23346: 1698392413...(1)
# Finished 23346: 0.11 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23346.gb
#
# Fetching 23347: 1698392418...(1)
# Finished 23347: 0.11 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23347.gb
#
# Fetching 23348: 1698392423...(1)
# Finished 23348: 0.11 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23348.gb
#
# Fetching 23349: 1698392428...(1)
# Finished 23349: 0.11 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23349.gb
#
# Fetching 23350: 1698392434...(1)
# Finished 23350: 0.09 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23350.gb
#
# Fetching 23351: 1698392438...(1)
# Finished 23351: 0.10 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23351.gb
#
# Fetching 23352: 1698392443...(1)
# Finished 23352: 0.11 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23352.gb
#
# Fetching 23353: 1698392448...(1)
# Finished 23353: 0.10 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23353.gb
#
# Fetching 23354: 1698392455...(1)
# Finished 23354: 0.10 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23354.gb
#
# Fetching 23355: 1698392459...(1)
# Finished 23355: 0.09 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23355.gb
#
# Fetching 23356: 1698392464...(1)
# Finished 23356: 0.09 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23356.gb
#
# Fetching 23357: 1698392470...(1)
# Finished 23357: 0.11 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23357.gb
#
# Fetching 23358: 1698392476...(1)
# Finished 23358: 0.10 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23358.gb
#
# Fetching 23359: 1698392481...(1)
# Finished 23359: 0.10 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23359.gb
#
# Fetching 23360: 1698392485...(1)
# Finished 23360: 0.09 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23360.gb
#
# Fetching 23361: 1698392489...(1)
# Finished 23361: 0.09 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23361.gb
#
# Fetching 23362: 1698392493...(1)
# Finished 23362: 0.09 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23362.gb
#
# Fetching 23363: 1698392497...(1)
# Finished 23363: 0.09 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23363.gb
#
# Fetching 23364: 1698392501...(1)
# Finished 23364: 0.09 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23364.gb
#
# Fetching 23365: 1698392505...(1)
# Finished 23365: 0.09 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23365.gb
#
# Fetching 23366: 1698392509...(1)
# Finished 23366: 0.09 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23366.gb
#
# Fetching 23367: 1698392513...(1)
# Finished 23367: 0.08 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23367.gb
#
# Fetching 23368: 1698392517...(1)
# Finished 23368: 0.09 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23368.gb
#
# Fetching 23369: 1698392522...(1)
# Finished 23369: 0.08 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23369.gb
#
# Fetching 23370: 1698392527...(1)
# Finished 23370: 0.08 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23370.gb
#
# Fetching 23371: 1698392531...(1)
# Finished 23371: 0.09 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23371.gb
#
# Fetching 23372: 1698392538...(1)
# Finished 23372: 0.09 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23372.gb
#
# Fetching 23373: 1698392544...(1)
# Finished 23373: 0.08 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23373.gb
#
# Fetching 23374: 1698392548...(1)
# Finished 23374: 0.08 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23374.gb
#
# Fetching 23375: 1698392552...(1)
# Finished 23375: 0.08 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23375.gb
#
# Fetching 23376: 1698392556...(1)
# Finished 23376: 0.08 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23376.gb
#
# Fetching 23377: 1698392560...(1)
# Finished 23377: 0.08 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23377.gb
#
# Fetching 23378: 1698392564...(1)
# Finished 23378: 0.08 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23378.gb
#
# Fetching 23379: 1698392568...(1)
# Finished 23379: 0.07 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23379.gb
#
# Fetching 23380: 1698392572...(1)
# Finished 23380: 0.07 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23380.gb
#
# Fetching 23381: 1698392576...(1)
# Finished 23381: 0.07 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23381.gb
#
# Fetching 23382: 1698392580...(1)
# Finished 23382: 0.07 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23382.gb
#
# Fetching 23383: 1698392585...(1)
# Finished 23383: 0.07 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23383.gb
#
# Fetching 23384: 1698392589...(1)
# Finished 23384: 0.07 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23384.gb
#
# Fetching 23385: 1698392592...(1)
# Finished 23385: 0.06 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23385.gb
#
# Fetching 23386: 1698392596...(1)
# Finished 23386: 0.07 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23386.gb
#
# Fetching 23387: 1698392600...(1)
# Finished 23387: 0.06 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23387.gb
#
# Fetching 23388: 1698392604...(1)
# Finished 23388: 0.07 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23388.gb
#
# Fetching 23389: 1698392608...(1)
# Finished 23389: 0.06 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23389.gb
#
# Fetching 23390: 1698392611...(1)
# Finished 23390: 0.06 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23390.gb
#
# Fetching 23391: 1698392615...(1)
# Finished 23391: 0.07 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23391.gb
#
# Fetching 23392: 1698392618...(1)
# Finished 23392: 0.06 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23392.gb
#
# Fetching 23393: 1698392622...(1)
# Finished 23393: 0.06 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23393.gb
#
# Fetching 23394: 1698392626...(1)
# Finished 23394: 0.06 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23394.gb
#
# Fetching 23395: 1698392629...(1)
# Finished 23395: 0.06 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23395.gb
#
# Fetching 23396: 1698392633...(1)
# Finished 23396: 0.06 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23396.gb
#
# Fetching 23397: 1698392636...(1)
# Finished 23397: 0.05 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23397.gb
#
# Fetching 23398: 1698392640...(1)
# Finished 23398: 0.05 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23398.gb
#
# Fetching 23399: 1698392643...(1)
# Finished 23399: 0.05 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23399.gb
#
# Fetching 23400: 1698392647...(1)
# Finished 23400: 0.05 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23400.gb
#
# Fetching 23401: 1698392650...(1)
# Finished 23401: 0.05 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23401.gb
#
# Fetching 23402: 1698392654...(1)
# Finished 23402: 0.05 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23402.gb
#
# Fetching 23403: 1698392657...(1)
# Finished 23403: 0.05 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23403.gb
#
# Fetching 23404: 1698392660...(1)
# Finished 23404: 0.05 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23404.gb
#
# Fetching 23405: 1698392664...(1)
# Finished 23405: 0.05 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23405.gb
#
# Fetching 23406: 1698392668...(1)
# Finished 23406: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23406.gb
#
# Fetching 23407: 1698392671...(1)
# Finished 23407: 0.05 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23407.gb
#
# Fetching 23408: 1698392674...(1)
# Finished 23408: 0.05 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23408.gb
#
# Fetching 23409: 1698392677...(1)
# Finished 23409: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23409.gb
#
# Fetching 23410: 1698392680...(1)
# Finished 23410: 0.05 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23410.gb
#
# Fetching 23411: 1698392683...(1)
# Finished 23411: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23411.gb
#
# Fetching 23412: 1698392686...(1)
# Finished 23412: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23412.gb
#
# Fetching 23413: 1698392689...(1)
# Finished 23413: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23413.gb
#
# Fetching 23414: 1698392692...(1)
# Finished 23414: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23414.gb
#
# Fetching 23415: 1698392695...(1)
# Finished 23415: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23415.gb
#
# Fetching 23416: 1698392698...(1)
# Finished 23416: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23416.gb
#
# Fetching 23417: 1698392701...(1)
# Finished 23417: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23417.gb
#
# Fetching 23418: 1698392704...(1)
# Finished 23418: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23418.gb
#
# Fetching 23419: 1698392708...(1)
# Finished 23419: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23419.gb
#
# Fetching 23420: 1698392711...(1)
# Finished 23420: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23420.gb
#
# Fetching 23421: 1698392715...(1)
# Finished 23421: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23421.gb
#
# Fetching 23422: 1698392719...(1)
# Finished 23422: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23422.gb
#
# Fetching 23423: 1698392722...(1)
# Finished 23423: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23423.gb
#
# Fetching 23424: 1698392725...(1)
# Finished 23424: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23424.gb
#
# Fetching 23425: 1698392728...(1)
# Finished 23425: 0.03 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23425.gb
#
# Fetching 23426: 1698392731...(1)
# Finished 23426: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23426.gb
#
# Fetching 23427: 1698392734...(1)
# Finished 23427: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23427.gb
#
# Fetching 23428: 1698392737...(1)
# Finished 23428: 0.03 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23428.gb
#
# Fetching 23429: 1698392740...(1)
# Finished 23429: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23429.gb
#
# Fetching 23430: 1698392743...(1)
# Finished 23430: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23430.gb
#
# Fetching 23431: 1698392746...(1)
# Finished 23431: 0.03 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23431.gb
#
# Fetching 23432: 1698392750...(1)
# Finished 23432: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23432.gb
#
# Fetching 23433: 1698392753...(1)
# Finished 23433: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23433.gb
#
# Fetching 23434: 1698392757...(1)
# Finished 23434: 0.03 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23434.gb
#
# Fetching 23435: 1698392760...(1)
# Finished 23435: 0.03 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23435.gb
#
# Fetching 23436: 1698392763...(1)
# Finished 23436: 0.03 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23436.gb
#
# Fetching 23437: 1698392766...(1)
# Finished 23437: 0.03 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23437.gb
#
# Fetching 23438: 1698392768...(1)
# Finished 23438: 0.03 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23438.gb
#
# Fetching 23439: 1698392771...(1)
# Finished 23439: 0.03 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23439.gb
#
# Fetching 23440: 1698392774...(1)
# Finished 23440: 0.02 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23440.gb
#
# Fetching 23441: 1698392777...(1)
# Finished 23441: 0.03 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23441.gb
#
# Fetching 23442: 1698392780...(1)
# Finished 23442: 0.02 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23442.gb
#
# Fetching 23443: 1698392783...(1)
# Finished 23443: 0.02 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23443.gb
#
# Fetching 23444: 1698392785...(1)
# Finished 23444: 0.02 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23444.gb
#
# Fetching 23445: 1698392788...(1)
# Finished 23445: 0.02 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23445.gb
#
# Fetching 23446: 1698392791...(1)
# Finished 23446: 0.02 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23446.gb
#
# Fetching 23447: 1698392794...(1)
# Finished 23447: 0.02 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23447.gb
#
# Fetching 23448: 1698392797...(1)
# Finished 23448: 0.02 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23448.gb
#
# Fetching 23449: 1698392800...(1)
# Finished 23449: 0.02 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23449.gb
#
# Fetching 23450: 1698392803...(1)
# Finished 23450: 0.02 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23450.gb
#
# Fetching 23451: 1698392806...(1)
# Finished 23451: 0.02 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23451.gb
#
# Fetching 23452: 1698392808...(1)
# Finished 23452: 0.02 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23452.gb
#
# Fetching 23453: 1698392811...(1)
# Finished 23453: 0.02 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23453.gb
#
# Fetching 23454: 1698392814...(1)
# Finished 23454: 0.02 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23454.gb
#
# Fetching 23455: 1698392816...(1)
# Finished 23455: 0.02 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23455.gb
#
# Fetching 23456: 1698392819...(1)
# Finished 23456: 0.02 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23456.gb
#
# Fetching 23457: 1698392822...(1)
# Finished 23457: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23457.gb
#
# Fetching 23458: 1698392825...(1)
# Finished 23458: 0.02 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23458.gb
#
# Fetching 23459: 1698392828...(1)
# Finished 23459: 0.02 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23459.gb
#
# Fetching 23460: 1698392831...(1)
# Finished 23460: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23460.gb
#
# Fetching 23461: 1698392834...(1)
# Finished 23461: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23461.gb
#
# Fetching 23462: 1698392838...(1)
# Finished 23462: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23462.gb
#
# Fetching 23463: 1698392841...(1)
# Finished 23463: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23463.gb
#
# Fetching 23464: 1698392843...(1)
# Finished 23464: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23464.gb
#
# Fetching 23465: 1698392846...(1)
# Finished 23465: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23465.gb
#
# Fetching 23466: 1698392849...(1)
# Finished 23466: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23466.gb
#
# Fetching 23467: 1698392852...(1)
# Finished 23467: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23467.gb
#
# Fetching 23468: 1698392855...(1)
# Finished 23468: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23468.gb
#
# Fetching 23469: 1698392859...(1)
# Finished 23469: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23469.gb
#
# Fetching 23470: 1698392861...(1)
# Finished 23470: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23470.gb
#
# Fetching 23471: 1698392865...(1)
# Finished 23471: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23471.gb
#
# Fetching 23472: 1698392867...(1)
# Finished 23472: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23472.gb
#
# Fetching 23473: 1698392870...(1)
# Finished 23473: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23473.gb
#
# Fetching 23474: 1698392873...(1)
# Finished 23474: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23474.gb
#
# Fetching 23475: 1698392876...(1)
# Finished 23475: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23475.gb
#
# Fetching 23476: 1698392879...(1)
# Finished 23476: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23476.gb
#
# Fetching 23477: 1698392882...(1)
# Finished 23477: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23477.gb
#
# Fetching 23478: 1698392885...(1)
# Finished 23478: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23478.gb
#
# Fetching 23479: 1698392887...(1)
# Finished 23479: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23479.gb
#
# Fetching 23480: 1698392890...(1)
# Finished 23480: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23480.gb
#
# Fetching 23481: 1698392893...(1)
# Finished 23481: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23481.gb
#
# Fetching 23482: 1698392895...(1)
# Finished 23482: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23482.gb
#
# Fetching 23483: 1698392898...(1)
# Finished 23483: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23483.gb
#
# Fetching 23484: 1698392900...(1)
# Finished 23484: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23484.gb
#
# Fetching 23485: 1698392903...(1)
# Finished 23485: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23485.gb
#
# Fetching 23486: 1698392906...(1)
# Finished 23486: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23486.gb
#
# Fetching 23487: 1698392909...(1)
# Finished 23487: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23487.gb
#
# Fetching 23488: 1698392912...(1)
# Finished 23488: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23488.gb
#
# Fetching 23489: 1698392914...(1)
# Finished 23489: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23489.gb
#
# Fetching 23490: 1698392917...(1)
# Finished 23490: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23490.gb
#
# Fetching 23491: 1698392920...(1)
# Finished 23491: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23491.gb
#
# Fetching 23492: 1698392923...(1)
# Finished 23492: 0.00 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23492.gb
#
# Fetching 23493: 1698392925...(1)
# Finished 23493: 0.00 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23493.gb
#
# Fetching 23494: 1698392928...(1)
# Finished 23494: 0.00 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23494.gb
#
# Fetching 23495: 1698392931...(1)
# Finished 23495: 0.00 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23495.gb
#
# Fetching 23496: 1698392933...(1)
# Finished 23496: 0.00 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23496.gb
#
# Fetching 23497: 1698392936...(1)
# Finished 23497: 0.00 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23497.gb
#
# Fetching 23498: 1698392939...(1)
# Finished 23498: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23498.gb
#
# Fetching 23499: 1698392941...(1)
# Finished 23499: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23499.gb
#
# Fetching 23500: 1698392944...(1)
# Finished 23500: 0.00 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23500.gb
#
# Fetching 23501: 1698392947...(1)
# Finished 23501: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23501.gb
#
# Fetching 23502: 1698392950...(1)
# Finished 23502: 0.00 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23502.gb
#
# Fetching 23503: 1698392953...(1)
# Finished 23503: 0.00 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23503.gb
#
# Fetching 23504: 1698392955...(1)
# Finished 23504: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23504.gb
#
# Fetching 23505: 1698392958...(1)
# Finished 23505: 0.00 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23505.gb
#
# Fetching 23506: 1698392961...(1)
# Finished 23506: 0.00 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23506.gb
#
# Fetching 23507: 1698392963...(1)
# Finished 23507: 0.00 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23507.gb
#
# Fetching 23508: 1698392966...(1)
# Finished 23508: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23508.gb
#
# Fetching 23509: 1698392969...(1)
# Finished 23509: 0.00 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23509.gb
#
# Fetching 23510: 1698392971...(1)
# Finished 23510: 0.00 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23510.gb
#
# Fetching 23511: 1698406973...(1)
# Finished 23511: 0.46 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23511.gb
#
# Fetching 23512: 1698406974...(1)
# Finished 23512: 0.45 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23512.gb
#
# Fetching 23513: 1698406975...(1)
# Finished 23513: 0.45 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23513.gb
#
# Fetching 23514: 1698406976...(1)
# Finished 23514: 0.35 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23514.gb
#
# Fetching 23515: 1698406977...(1)
# Finished 23515: 0.38 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23515.gb
#
# Fetching 23516: 1698406978...(1)
# Finished 23516: 0.37 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23516.gb
#
# Fetching 23517: 1698406979...(1)
# Finished 23517: 0.35 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23517.gb
#
# Fetching 23518: 1698406980...(1)
# Finished 23518: 0.34 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23518.gb
#
# Fetching 23519: 1698406981...(1)
# Finished 23519: 0.35 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23519.gb
#
# Fetching 23520: 1698406982...(1)
# Finished 23520: 0.34 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23520.gb
#
# Fetching 23521: 1698406983...(1)
# Finished 23521: 0.31 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23521.gb
#
# Fetching 23522: 1698406984...(1)
# Finished 23522: 0.28 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23522.gb
#
# Fetching 23523: 1698406985...(1)
# Finished 23523: 0.30 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23523.gb
#
# Fetching 23524: 1698406986...(1)
# Finished 23524: 0.30 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23524.gb
#
# Fetching 23525: 1698406987...(1)
# Finished 23525: 0.26 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23525.gb
#
# Fetching 23526: 1698406988...(1)
# Finished 23526: 0.27 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23526.gb
#
# Fetching 23527: 1698406989...(1)
# Finished 23527: 0.26 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23527.gb
#
# Fetching 23528: 1698406990...(1)
# Finished 23528: 0.26 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23528.gb
#
# Fetching 23529: 1698406991...(1)
# Finished 23529: 0.25 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23529.gb
#
# Fetching 23530: 1698406992...(1)
# Finished 23530: 0.22 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23530.gb
#
# Fetching 23531: 1698406993...(1)
# Finished 23531: 0.23 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23531.gb
#
# Fetching 23532: 1698406994...(1)
# Finished 23532: 0.24 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23532.gb
#
# Fetching 23533: 1698406995...(1)
# Finished 23533: 0.25 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23533.gb
#
# Fetching 23534: 1698406996...(1)
# Finished 23534: 0.23 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23534.gb
#
# Fetching 23535: 1698406997...(1)
# Finished 23535: 0.24 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23535.gb
#
# Fetching 23536: 1698406998...(1)
# Finished 23536: 0.18 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23536.gb
#
# Fetching 23537: 1698406999...(1)
# Finished 23537: 0.20 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23537.gb
#
# Fetching 23538: 1698407000...(1)
# Finished 23538: 0.20 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23538.gb
#
# Fetching 23539: 1698407001...(1)
# Finished 23539: 0.20 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23539.gb
#
# Fetching 23540: 1698407002...(1)
# Finished 23540: 0.19 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23540.gb
#
# Fetching 23541: 1698407003...(1)
# Finished 23541: 0.18 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23541.gb
#
# Fetching 23542: 1698407004...(1)
# Finished 23542: 0.18 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23542.gb
#
# Fetching 23543: 1698407005...(1)
# Finished 23543: 0.17 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23543.gb
#
# Fetching 23544: 1698407006...(1)
# Finished 23544: 0.17 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23544.gb
#
# Fetching 23545: 1698407007...(1)
# Finished 23545: 0.16 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23545.gb
#
# Fetching 23546: 1698407008...(1)
# Finished 23546: 0.17 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23546.gb
#
# Fetching 23547: 1698407009...(1)
# Finished 23547: 0.16 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23547.gb
#
# Fetching 23548: 1698407010...(1)
# Finished 23548: 0.15 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23548.gb
#
# Fetching 23549: 1698407011...(1)
# Finished 23549: 0.16 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23549.gb
#
# Fetching 23550: 1698407012...(1)
# Finished 23550: 0.16 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23550.gb
#
# Fetching 23551: 1698407013...(1)
# Finished 23551: 0.15 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23551.gb
#
# Fetching 23552: 1698407014...(1)
# Finished 23552: 0.16 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23552.gb
#
# Fetching 23553: 1698407015...(1)
# Finished 23553: 0.14 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23553.gb
#
# Fetching 23554: 1698407016...(1)
# Finished 23554: 0.14 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23554.gb
#
# Fetching 23555: 1698407017...(1)
# Finished 23555: 0.15 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23555.gb
#
# Fetching 23556: 1698407018...(1)
# Finished 23556: 0.15 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23556.gb
#
# Fetching 23557: 1698407019...(1)
# Finished 23557: 0.14 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23557.gb
#
# Fetching 23558: 1698407020...(1)
# Finished 23558: 0.14 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23558.gb
#
# Fetching 23559: 1698407021...(1)
# Finished 23559: 0.14 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23559.gb
#
# Fetching 23560: 1698407022...(1)
# Finished 23560: 0.13 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23560.gb
#
# Fetching 23561: 1698407023...(1)
# Finished 23561: 0.14 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23561.gb
#
# Fetching 23562: 1698407024...(1)
# Finished 23562: 0.14 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23562.gb
#
# Fetching 23563: 1698407025...(1)
# Finished 23563: 0.13 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23563.gb
#
# Fetching 23564: 1698407026...(1)
# Finished 23564: 0.13 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23564.gb
#
# Fetching 23565: 1698407027...(1)
# Finished 23565: 0.13 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23565.gb
#
# Fetching 23566: 1698407028...(1)
# Finished 23566: 0.12 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23566.gb
#
# Fetching 23567: 1698407029...(1)
# Finished 23567: 0.14 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23567.gb
#
# Fetching 23568: 1698407030...(1)
# Finished 23568: 0.13 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23568.gb
#
# Fetching 23569: 1698407031...(1)
# Finished 23569: 0.13 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23569.gb
#
# Fetching 23570: 1698407032...(1)
# Finished 23570: 0.14 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23570.gb
#
# Fetching 23571: 1698407033...(1)
# Finished 23571: 0.13 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23571.gb
#
# Fetching 23572: 1698407034...(1)
# Finished 23572: 0.11 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23572.gb
#
# Fetching 23573: 1698407035...(1)
# Finished 23573: 0.12 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23573.gb
#
# Fetching 23574: 1698407036...(1)
# Finished 23574: 0.12 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23574.gb
#
# Fetching 23575: 1698407037...(1)
# Finished 23575: 0.12 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23575.gb
#
# Fetching 23576: 1698407038...(1)
# Finished 23576: 0.12 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23576.gb
#
# Fetching 23577: 1698407039...(1)
# Finished 23577: 0.12 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23577.gb
#
# Fetching 23578: 1698407040...(1)
# Finished 23578: 0.10 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23578.gb
#
# Fetching 23579: 1698407041...(1)
# Finished 23579: 0.11 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23579.gb
#
# Fetching 23580: 1698407042...(1)
# Finished 23580: 0.11 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23580.gb
#
# Fetching 23581: 1698407043...(1)
# Finished 23581: 0.11 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23581.gb
#
# Fetching 23582: 1698407044...(1)
# Finished 23582: 0.11 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23582.gb
#
# Fetching 23583: 1698407045...(1)
# Finished 23583: 0.11 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23583.gb
#
# Fetching 23584: 1698407046...(1)
# Finished 23584: 0.10 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23584.gb
#
# Fetching 23585: 1698407047...(1)
# Finished 23585: 0.10 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23585.gb
#
# Fetching 23586: 1698407048...(1)
# Finished 23586: 0.10 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23586.gb
#
# Fetching 23587: 1698407049...(1)
# Finished 23587: 0.10 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23587.gb
#
# Fetching 23588: 1698407050...(1)
# Finished 23588: 0.10 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23588.gb
#
# Fetching 23589: 1698407051...(1)
# Finished 23589: 0.10 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23589.gb
#
# Fetching 23590: 1698407052...(1)
# Finished 23590: 0.09 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23590.gb
#
# Fetching 23591: 1698407053...(1)
# Finished 23591: 0.09 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23591.gb
#
# Fetching 23592: 1698407054...(1)
# Finished 23592: 0.09 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23592.gb
#
# Fetching 23593: 1698407055...(1)
# Finished 23593: 0.09 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23593.gb
#
# Fetching 23594: 1698407056...(1)
# Finished 23594: 0.09 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23594.gb
#
# Fetching 23595: 1698407057...(1)
# Finished 23595: 0.08 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23595.gb
#
# Fetching 23596: 1698407058...(1)
# Finished 23596: 0.09 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23596.gb
#
# Fetching 23597: 1698407059...(1)
# Finished 23597: 0.09 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23597.gb
#
# Fetching 23598: 1698407060...(1)
# Finished 23598: 0.08 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23598.gb
#
# Fetching 23599: 1698407061...(1)
# Finished 23599: 0.08 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23599.gb
#
# Fetching 23600: 1698407062...(1)
# Finished 23600: 0.08 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23600.gb
#
# Fetching 23601: 1698407063...(1)
# Finished 23601: 0.09 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23601.gb
#
# Fetching 23602: 1698407064...(1)
# Finished 23602: 0.09 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23602.gb
#
# Fetching 23603: 1698407065...(1)
# Finished 23603: 0.08 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23603.gb
#
# Fetching 23604: 1698407066...(1)
# Finished 23604: 0.08 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23604.gb
#
# Fetching 23605: 1698407067...(1)
# Finished 23605: 0.08 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23605.gb
#
# Fetching 23606: 1698407068...(1)
# Finished 23606: 0.08 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23606.gb
#
# Fetching 23607: 1698407069...(1)
# Finished 23607: 0.08 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23607.gb
#
# Fetching 23608: 1698407070...(1)
# Finished 23608: 0.07 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23608.gb
#
# Fetching 23609: 1698407071...(1)
# Finished 23609: 0.08 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23609.gb
#
# Fetching 23610: 1698407072...(1)
# Finished 23610: 0.07 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23610.gb
#
# Fetching 23611: 1698407073...(1)
# Finished 23611: 0.07 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23611.gb
#
# Fetching 23612: 1698407074...(1)
# Finished 23612: 0.08 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23612.gb
#
# Fetching 23613: 1698407075...(1)
# Finished 23613: 0.07 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23613.gb
#
# Fetching 23614: 1698407076...(1)
# Finished 23614: 0.07 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23614.gb
#
# Fetching 23615: 1698407077...(1)
# Finished 23615: 0.07 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23615.gb
#
# Fetching 23616: 1698407078...(1)
# Finished 23616: 0.07 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23616.gb
#
# Fetching 23617: 1698407079...(1)
# Finished 23617: 0.08 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23617.gb
#
# Fetching 23618: 1698407080...(1)
# Finished 23618: 0.07 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23618.gb
#
# Fetching 23619: 1698407081...(1)
# Finished 23619: 0.07 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23619.gb
#
# Fetching 23620: 1698407082...(1)
# Finished 23620: 0.07 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23620.gb
#
# Fetching 23621: 1698407083...(1)
# Finished 23621: 0.06 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23621.gb
#
# Fetching 23622: 1698407084...(1)
# Finished 23622: 0.06 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23622.gb
#
# Fetching 23623: 1698407085...(1)
# Finished 23623: 0.06 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23623.gb
#
# Fetching 23624: 1698407086...(1)
# Finished 23624: 0.06 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23624.gb
#
# Fetching 23625: 1698407087...(1)
# Finished 23625: 0.06 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23625.gb
#
# Fetching 23626: 1698407088...(1)
# Finished 23626: 0.06 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23626.gb
#
# Fetching 23627: 1698407089...(1)
# Finished 23627: 0.06 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23627.gb
#
# Fetching 23628: 1698407090...(1)
# Finished 23628: 0.06 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23628.gb
#
# Fetching 23629: 1698407091...(1)
# Finished 23629: 0.06 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23629.gb
#
# Fetching 23630: 1698407092...(1)
# Finished 23630: 0.05 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23630.gb
#
# Fetching 23631: 1698407093...(1)
# Finished 23631: 0.05 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23631.gb
#
# Fetching 23632: 1698407094...(1)
# Finished 23632: 0.06 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23632.gb
#
# Fetching 23633: 1698407095...(1)
# Finished 23633: 0.05 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23633.gb
#
# Fetching 23634: 1698407096...(1)
# Finished 23634: 0.05 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23634.gb
#
# Fetching 23635: 1698407097...(1)
# Finished 23635: 0.05 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23635.gb
#
# Fetching 23636: 1698407098...(1)
# Finished 23636: 0.05 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23636.gb
#
# Fetching 23637: 1698407099...(1)
# Finished 23637: 0.05 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23637.gb
#
# Fetching 23638: 1698407100...(1)
# Finished 23638: 0.05 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23638.gb
#
# Fetching 23639: 1698407101...(1)
# Finished 23639: 0.05 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23639.gb
#
# Fetching 23640: 1698407102...(1)
# Finished 23640: 0.05 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23640.gb
#
# Fetching 23641: 1698407103...(1)
# Finished 23641: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23641.gb
#
# Fetching 23642: 1698407104...(1)
# Finished 23642: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23642.gb
#
# Fetching 23643: 1698407105...(1)
# Finished 23643: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23643.gb
#
# Fetching 23644: 1698407106...(1)
# Finished 23644: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23644.gb
#
# Fetching 23645: 1698407107...(1)
# Finished 23645: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23645.gb
#
# Fetching 23646: 1698407108...(1)
# Finished 23646: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23646.gb
#
# Fetching 23647: 1698407109...(1)
# Finished 23647: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23647.gb
#
# Fetching 23648: 1698407110...(1)
# Finished 23648: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23648.gb
#
# Fetching 23649: 1698407111...(1)
# Finished 23649: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23649.gb
#
# Fetching 23650: 1698407112...(1)
# Finished 23650: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23650.gb
#
# Fetching 23651: 1698407113...(1)
# Finished 23651: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23651.gb
#
# Fetching 23652: 1698407114...(1)
# Finished 23652: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23652.gb
#
# Fetching 23653: 1698407115...(1)
# Finished 23653: 0.04 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23653.gb
#
# Fetching 23654: 1698407116...(1)
# Finished 23654: 0.03 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23654.gb
#
# Fetching 23655: 1698407117...(1)
# Finished 23655: 0.03 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23655.gb
#
# Fetching 23656: 1698407118...(1)
# Finished 23656: 0.03 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23656.gb
#
# Fetching 23657: 1698407119...(1)
# Finished 23657: 0.03 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23657.gb
#
# Fetching 23658: 1698407120...(1)
# Finished 23658: 0.03 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23658.gb
#
# Fetching 23659: 1698407121...(1)
# Finished 23659: 0.03 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23659.gb
#
# Fetching 23660: 1698407122...(1)
# Finished 23660: 0.03 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23660.gb
#
# Fetching 23661: 1698407123...(1)
# Finished 23661: 0.03 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23661.gb
#
# Fetching 23662: 1698407124...(1)
# Finished 23662: 0.03 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23662.gb
#
# Fetching 23663: 1698407125...(1)
# Finished 23663: 0.03 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23663.gb
#
# Fetching 23664: 1698407126...(1)
# Finished 23664: 0.03 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23664.gb
#
# Fetching 23665: 1698407127...(1)
# Finished 23665: 0.02 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23665.gb
#
# Fetching 23666: 1698407128...(1)
# Finished 23666: 0.03 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23666.gb
#
# Fetching 23667: 1698407129...(1)
# Finished 23667: 0.03 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23667.gb
#
# Fetching 23668: 1698407130...(1)
# Finished 23668: 0.03 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23668.gb
#
# Fetching 23669: 1698407131...(1)
# Finished 23669: 0.03 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23669.gb
#
# Fetching 23670: 1698407132...(1)
# Finished 23670: 0.02 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23670.gb
#
# Fetching 23671: 1698407133...(1)
# Finished 23671: 0.02 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23671.gb
#
# Fetching 23672: 1698407134...(1)
# Finished 23672: 0.02 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23672.gb
#
# Fetching 23673: 1698407135...(1)
# Finished 23673: 0.02 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23673.gb
#
# Fetching 23674: 1698407136...(1)
# Finished 23674: 0.02 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23674.gb
#
# Fetching 23675: 1698407137...(1)
# Finished 23675: 0.02 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23675.gb
#
# Fetching 23676: 1698407138...(1)
# Finished 23676: 0.03 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23676.gb
#
# Fetching 23677: 1698407139...(1)
# Finished 23677: 0.03 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23677.gb
#
# Fetching 23678: 1698407140...(1)
# Finished 23678: 0.02 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23678.gb
#
# Fetching 23679: 1698407141...(1)
# Finished 23679: 0.02 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23679.gb
#
# Fetching 23680: 1698407142...(1)
# Finished 23680: 0.02 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23680.gb
#
# Fetching 23681: 1698407143...(1)
# Finished 23681: 0.02 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23681.gb
#
# Fetching 23682: 1698407144...(1)
# Finished 23682: 0.02 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_23682.gb
#
# Fetching 23683: 1698407145...(1)
# ...
# Finished 27487: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27487.gb
#
# Fetching 27488: 981217051...(1)
# Finished 27488: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27488.gb
#
# Fetching 27489: 981217052...(1)
# Finished 27489: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27489.gb
#
# Fetching 27490: 981217053...(1)
# Finished 27490: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27490.gb
#
# Fetching 27491: 981217054...(1)
# Finished 27491: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27491.gb
#
# Fetching 27492: 981217055...(1)
# Finished 27492: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27492.gb
#
# Fetching 27493: 981217056...(1)
# Finished 27493: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27493.gb
#
# Fetching 27494: 981217057...(1)
# Finished 27494: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27494.gb
#
# Fetching 27495: 981217058...(1)
# Finished 27495: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27495.gb
#
# Fetching 27496: 981217059...(1)
# Finished 27496: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27496.gb
#
# Fetching 27497: 981217060...(1)
# Finished 27497: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27497.gb
#
# Fetching 27498: 981217061...(1)
# Finished 27498: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27498.gb
#
# Fetching 27499: 981217062...(1)
# Finished 27499: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27499.gb
#
# Fetching 27500: 981217063...(1)
# Finished 27500: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27500.gb
#
# Fetching 27501: 981217064...(1)
# Finished 27501: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27501.gb
#
# Fetching 27502: 981217065...(1)
# Finished 27502: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27502.gb
#
# Fetching 27503: 981217066...(1)
# Finished 27503: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27503.gb
#
# Fetching 27504: 981217067...(1)
# Finished 27504: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27504.gb
#
# Fetching 27505: 981217068...(1)
# Finished 27505: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27505.gb
#
# Fetching 27506: 981217069...(1)
# Finished 27506: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27506.gb
#
# Fetching 27507: 981217070...(1)
# Finished 27507: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27507.gb
#
# Fetching 27508: 981217071...(1)
# Finished 27508: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27508.gb
#
# Fetching 27509: 981217072...(1)
# Finished 27509: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27509.gb
#
# Fetching 27510: 981217073...(1)
# Finished 27510: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27510.gb
#
# Fetching 27511: 981217074...(1)
# Finished 27511: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27511.gb
#
# Fetching 27512: 981217075...(1)
# Finished 27512: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27512.gb
#
# Fetching 27513: 981217076...(1)
# Finished 27513: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27513.gb
#
# Fetching 27514: 981217077...(1)
# Finished 27514: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27514.gb
#
# Fetching 27515: 981217078...(1)
# Finished 27515: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27515.gb
#
# Fetching 27516: 981217079...(1)
# Finished 27516: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27516.gb
#
# Fetching 27517: 981217080...(1)
# Finished 27517: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27517.gb
#
# Fetching 27518: 981217081...(1)
# Finished 27518: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27518.gb
#
# Fetching 27519: 981217082...(1)
# Finished 27519: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27519.gb
#
# Fetching 27520: 981217083...(1)
# Finished 27520: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27520.gb
#
# Fetching 27521: 981217084...(1)
# Finished 27521: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27521.gb
#
# Fetching 27522: 981217085...(1)
# Finished 27522: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27522.gb
#
# Fetching 27523: 981217086...(1)
# Finished 27523: 0.01 MB /mnt/sdb/wcs/NCBI-myxobacterial-genome/txid29_No_27523.gb
#
# Group finished, already got 2283.12 MB data!
# Finished fetching all IDs.
# Process Process-17194:
# Process Process-18468:
# Process Process-18353:
# Process Process-17120:
# Process Process-17133:
# Process Process-1:
# Process Process-18454:
# Process Process-17568:
# Process Process-18479:
# Traceback (most recent call last):
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "<ipython-input-5-be08f5423696>", line 21, in fetch
#     out_handle.write(handle.read())
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/http/client.py", line 461, in read
#     return self._readall_chunked()
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/http/client.py", line 571, in _readall_chunked
#     value.append(self._safe_read(chunk_left))
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-5-be08f5423696>", line 21, in fetch
#     out_handle.write(handle.read())
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/http/client.py", line 608, in _safe_read
#     data = self.fp.read(amt)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-5-be08f5423696>", line 21, in fetch
#     out_handle.write(handle.read())
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "<ipython-input-5-be08f5423696>", line 21, in fetch
#     out_handle.write(handle.read())
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/http/client.py", line 461, in read
#     return self._readall_chunked()
#   File "<ipython-input-5-be08f5423696>", line 21, in fetch
#     out_handle.write(handle.read())
#   File "<ipython-input-5-be08f5423696>", line 21, in fetch
#     out_handle.write(handle.read())
#   File "<ipython-input-5-be08f5423696>", line 21, in fetch
#     out_handle.write(handle.read())
#   File "<ipython-input-5-be08f5423696>", line 21, in fetch
#     out_handle.write(handle.read())
#   File "<ipython-input-5-be08f5423696>", line 21, in fetch
#     out_handle.write(handle.read())
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/http/client.py", line 461, in read
#     return self._readall_chunked()
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/http/client.py", line 461, in read
#     return self._readall_chunked()
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/http/client.py", line 571, in _readall_chunked
#     value.append(self._safe_read(chunk_left))
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/http/client.py", line 461, in read
#     return self._readall_chunked()
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/http/client.py", line 461, in read
#     return self._readall_chunked()
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/http/client.py", line 461, in read
#     return self._readall_chunked()
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/http/client.py", line 461, in read
#     return self._readall_chunked()
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/http/client.py", line 461, in read
#     return self._readall_chunked()
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/http/client.py", line 571, in _readall_chunked
#     value.append(self._safe_read(chunk_left))
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/http/client.py", line 571, in _readall_chunked
#     value.append(self._safe_read(chunk_left))
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/http/client.py", line 571, in _readall_chunked
#     value.append(self._safe_read(chunk_left))
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/http/client.py", line 608, in _safe_read
#     data = self.fp.read(amt)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/http/client.py", line 571, in _readall_chunked
#     value.append(self._safe_read(chunk_left))
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/http/client.py", line 568, in _readall_chunked
#     chunk_left = self._get_chunk_left()
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/http/client.py", line 571, in _readall_chunked
#     value.append(self._safe_read(chunk_left))
# KeyboardInterrupt
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/http/client.py", line 571, in _readall_chunked
#     value.append(self._safe_read(chunk_left))
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/http/client.py", line 608, in _safe_read
#     data = self.fp.read(amt)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/http/client.py", line 608, in _safe_read
#     data = self.fp.read(amt)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/http/client.py", line 608, in _safe_read
#     data = self.fp.read(amt)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/http/client.py", line 608, in _safe_read
#     data = self.fp.read(amt)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/http/client.py", line 608, in _safe_read
#     data = self.fp.read(amt)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/http/client.py", line 551, in _get_chunk_left
#     chunk_left = self._read_next_chunk_size()
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/http/client.py", line 608, in _safe_read
#     data = self.fp.read(amt)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/http/client.py", line 511, in _read_next_chunk_size
#     line = self.fp.readline(_MAXLINE + 1)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# KeyboardInterrupt
#   File "/mnt/sdb/wcs/.conda/envs/jupyter-install/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# KeyboardInterrupt
# KeyboardInterrupt

# %% [markdown]
# # Convert genbank file to blast database

# %% [markdown]
# gb files needs to be converet to fasta file before making a database
# also the files needed to be combined incase combine blast database don't work, also for easy file transfering

# %%
def convertGb2Fasta(storage_folder_gb, storage_folder_fa, logFile, sizeLimit, numFilesToConvert = 99999):
    print('Changing gb to fasta...')
    
    totalGbs = [int(file.split('.')[0].split('_')[-1]) for file in os.listdir(storage_folder_gb) if file.endswith('gb')]
    totalGbs.sort()

    
    # write log file
    writeLog(logFile, f'\n{timestamp:*^50}\n{totalGbs[-1]} of gb files in total\n{"":*^50}\n')
    # setup starting values
    recordWithSeq = [] # container for seqs for the function of dumping certain size of seqs together.
    seqTotalLength = 0
    num_empty = 0
    breakPoint = 0
    
    # Main loop
    for i in totalGbs:
        num = str(i).zfill(5)
        input_file = os.path.join(storage_folder_gb, f'{prefix}_No_{num}.gb') 
        # If there is a gap in the input file, it will currupt here.

        # Write note to screen and log file
        if i%5 ==0:
            writeLog(logFile, f"{num}|{seqTotalLength}", end = '\t')
            if i%25 ==0:
                writeLog(logFile, '')
            
        records = SeqIO.parse(input_file, 'genbank')
        for record in records:
            if type(record.seq) == Seq.UnknownSeq: # Empty records will load as UnknownSeq
                num_empty += 1
                pass
            else:
                recordWithSeq.append(record)
                seqTotalLength += len(record)
        if seqTotalLength >= sizeLimit:
            writeLog(logFile, '\nReach the size limit of single file, writing it out')
            output_file = os.path.join(storage_folder_fa, f'{prefix}_No_{breakPoint}to{num}.fasta')
            with open(output_file, 'w') as fasta_out_handle:
                if len(recordWithSeq) == 0: # if all records are empty, there is no point of writing it to fasta
                    writeLog(logFile, f'There is no sequence in this batch, proceed to next file...')
                else:
                    SeqIO.write(recordWithSeq, fasta_out_handle, 'fasta')
                    writeLog(logFile, f"Finished converting {num}, ignored {num_empty} empty records in this batch.")
            # Reset batch
            recordWithSeq = list()
            seqTotalLength = 0
            num_empty = 0
            breakPoint = str(i).zfill(5)
    writeLog(logFile, '\nReach the end, writing it out...')
    output_file = os.path.join(storage_folder_fa, f'{prefix}_No_{breakPoint}to{num}.fasta')
    with open(output_file, 'w') as fasta_out_handle:
        if len(recordWithSeq) == 0: # if all records are empty, there is no point of writing it to fasta
            writeLog(logFile, f'There is no sequence in this last batch.')
        else:
            SeqIO.write(recordWithSeq, fasta_out_handle, 'fasta')
            writeLog(logFile, f"Finished converting {num}, ignored {num_empty} empty records in this batch.")

            
            
timestamp = strftime('%X %d/%m/%Y %Z')
fastaFolder = '/mnt/sdb/wcs/NCBI-myxobacterial-genome/fasta'
fetched = '/mnt/sdb/wcs/NCBI-myxobacterial-genome'
if not os.path.isdir(fastaFolder):
    os.mkdir(fastaFolder)
logFile = os.path.join(fastaFolder,'converting.log')
print('Converting...')
sizeLimit = 400000000 # if the file is bigger than 400 M, program will write it out and start a new file

convertGb2Fasta(fetched,fastaFolder,logFile,sizeLimit)

# %%
def combineGenbank(fetchedGenbank,combinedGenbank,logFile,sizeLimit,startFileNum = 0):
    if not os.path.isdir(combinedGenbank):
        os.mkdir(combinedGenbank)

    fileList = [os.path.join(fetchedGenbank, file) for file in os.listdir(fetchedGenbank) if file.endswith('.gb')]
    seqTotalLength = 0
    seqsInOneFile = []
    breakPoint = startFileNum
    for i in range(startFileNum, len(fileList)):
        parseSeqs = list(SeqIO.parse(fileList[i],'genbank'))
        for seq in parseSeqs:
            seqTotalLength += len(seq)
            if len(seq) == 0:
                print('There is 0 length sequences')
                break
        seqsInOneFile += parseSeqs
        logStr = f"{i}|{seqTotalLength}"
        writeLog(logFile, logStr, end = '\t')

        if i == len(fileList) - 1:
            outputFile = os.path.join(combinedGenbank, f'{prefix}_{breakPoint}_to_{i}.gb')
            logStr = f'\nFinished combining, write out last batch...\n{outputFile}'
            writeLog(logFile, logStr)
            SeqIO.write(seqsInOneFile, outputFile, 'genbank')
            writeLog(logFile, 'Write succeeded.')
        elif seqTotalLength >= sizeLimit:
            outputFile = os.path.join(combinedGenbank, f'{prefix}_{breakPoint}_to_{i}.gb')
            logStr = f'\nReached file size limit, write out...\n{outputFile}'
            writeLog(logFile, logStr)
            SeqIO.write(seqsInOneFile, outputFile, 'genbank')
            breakPoint = i+1
            seqsInOneFile = []
            seqTotalLength = 0
            writeLog(logFile, 'Write succeeded.')

            
timestamp = strftime('%X %d/%m/%Y %Z')
combinedFolder = r"/mnt/sdb/wcs/NCBI-myxobacterial-genome"
sourceFolder = r"/mnt/sdb/wcs/NCBI-myxobacterial-genome"
logFile = os.path.join(combinedFolder,'converting.log')
print('Converting...')
sizeLimit = 1000000000

# 1000000000 cost about 4-6 GB memory for genbank files, result ~2.5 GB file.
startFileNum = 624
combineGenbank(sourceFolder,combinedFolder,logFile,sizeLimit,startFileNum)

# %% [markdown]
# # Make blast database

# %%
sourceDir = '/mnt/sdb/wcs/NCBI-myxobacterial-genome/fasta'
outputDir = '/mnt/sdb/wcs/NCBI-myxobacterial-genome/db'
logFile = '/mnt/sdb/wcs/NCBI-myxobacterial-genome/db/mkdb.log'

if not os.path.isdir(outputDir):
    os.mkdir(outputDir)
    
# Change here accroding to the format fetched from entrez 
totalNum = sum(file.endswith('fasta') for file in os.listdir(sourceDir))
print(f'Total number of files to be converted {totalNum}.\nConverted:', end='')

converted = 0
for file in os.listdir(sourceDir):
    if not file.endswith('fasta'):
        continue
    singleSeqFile = os.path.join(sourceDir, file)
    args = ['makeblastdb',
            '-in', singleSeqFile,
            '-input_type', 'fasta',
            '-dbtype', 'nucl',
            '-title', f'{file[:-6]}',
            '-out', os.path.join(outputDir, f'{file[:-6]}_nucl'),
            '-logfile', logFile,
            '-taxid', '29'
           ]
    run = subprocess.run(args, stdout = subprocess.PIPE, stderr = subprocess.PIPE)
    if run.returncode == 0:
        converted += 1
        print(f'{converted}|', end = '')
        pass
    else:
        with open(logFile, 'r') as log:
            for line in log.readlines():
                print(line)
        break
print(f'\n\nFinished, databases made: {converted}')
# Out:
# Total number of files to be converted 3.
# Converted:1|2|3|
#
# Finished, databases made: 3

# %% [markdown]
# ## Merge blast database into one

# %%
databaseDir = '/mnt/sdb/wcs/NCBI-myxobacterial-genome/db'
listFile = '/mnt/sdb/wcs/NCBI-myxobacterial-genome/db/listofdbs.txt'
databaseList = []
for file in os.listdir(databaseDir):
    if not file.endswith('nsq'):
        continue
    dbName = file.split('.')[0]
    databaseList.append(os.path.join(databaseDir, dbName))
with open(listFile, 'w') as handle:
    handle.write('\n'.join(databaseList))
    
args = ['blastdb_aliastool',
        '-dblist_file', listFile,
        '-dbtype', 'nucl',
        '-out', os.path.join(databaseDir, f'{prefix}Nucl{dateOfSearch}'),
        '-title', f'{prefix}Nucl{dateOfSearch}',
       ]
run = subprocess.run(args, stdout = subprocess.PIPE, stderr = subprocess.PIPE)
if run.returncode == 0:
    pass
else:
    print(run.stdout.decode())
    print(run.stderr.decode())
